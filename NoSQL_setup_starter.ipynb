# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json `

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pymongo

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'classDB', 'company', 'config', 'epa', 'fruits_db', 'gardenDB', 'local', 'met', 'petsitly_marketing', 'test', 'travel_db', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
pprint(db['establishments'].find_one(), indent=4)
# Out:
# {   'AddressLine1': 'The Bay',
#     'AddressLine2': 'St Margarets Bay',
#     'AddressLine3': 'Kent',
#     'AddressLine4': '',
#     'BusinessName': 'Refreshment Kiosk',
#     'BusinessType': 'Restaurant/Cafe/Canteen',
#     'BusinessTypeID': 1,
#     'ChangesByServerID': 0,
#     'Distance': 4587.347174863443,
#     'FHRSID': 254719,
#     'LocalAuthorityBusinessID': 'PI/000069980',
#     'LocalAuthorityCode': '182',
#     'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#     'LocalAuthorityName': 'Dover',
#     'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#     'NewRatingPending': False,
#     'Phone': '',
#     'PostCode': 'CT15 6DY',
#     'RatingDate': '2022-03-24T00:00:00',
#     'RatingKey': 'fhrs_5_en-gb',
#     'RatingValue': '5',
#     'RightToReply': '',
#     'SchemeType': 'FHRS',
#     '_id': ObjectId('640689993c7f636ebc395548'),
#     'geocode': {'latitude': '51.152225', 'longitude': '1.387974'},
#     'links': [   {   'href': 'https://api.ratings.food.gov.uk/establishments/254719',
#                      'rel': 'self'}],
#     'meta': {   'dataSource': None,
#                 'extractDate': '0001-01-01T00:00:00',
#                 'itemCount': 0,
#                 'pageNumber': 0,
#                 'pageSize': 0,
#                 'returncode': None,
#                 'totalCount': 0,
#                 'totalPages': 0},
#     'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}

# %%
# assign the collection to a variable
coll = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
update_dict = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
coll.insert_one(update_dict)

# %%
# Check that the new restaurant was inserted
pprint(coll.find_one(update_dict), indent=4)
# Out:
# {   'AddressLine1': 'Penang Flavours',
#     'AddressLine2': '146A Plumstead Rd',
#     'AddressLine3': 'London',
#     'AddressLine4': '',
#     'BusinessName': 'Penang Flavours',
#     'BusinessType': 'Restaurant/Cafe/Canteen',
#     'BusinessTypeID': '',
#     'Distance': 4623.972328074718,
#     'LocalAuthorityCode': '511',
#     'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#     'LocalAuthorityName': 'Greenwich',
#     'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#     'NewRatingPending': True,
#     'Phone': '',
#     'PostCode': 'SE18 7DY',
#     'RightToReply': '',
#     'SchemeType': 'FHRS',
#     '_id': ObjectId('640689a562e7a426474105bc'),
#     'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#     'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
fields = {"BusinessTypeID":1, "BusinessType":1}
bs_type = list(coll.find({"BusinessType":"Restaurant/Cafe/Canteen"},fields))
pprint(bs_type, indent=4)
# Out:
# [   {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395548')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39554a')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39554b')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39554d')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395551')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395553')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395556')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39555b')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39555c')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39555d')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39555f')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395560')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395568')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395571')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395576')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395577')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395579')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39557a')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39557c')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395583')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395584')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395585')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395586')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395587')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395588')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39558b')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39558d')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395591')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395592')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395596')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395597')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395599')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39559a')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39559d')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39559e')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39559f')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3955ac')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3955ae')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3955b1')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3955b4')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3955b5')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3955b7')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3955b9')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3955ba')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3955c3')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3955c4')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3955c6')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3955cb')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3955cf')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3955d1')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3955d2')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3955d8')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3955db')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3955de')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3955df')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3955e0')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3955e8')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3955ef')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3955f0')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3955f3')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3955f5')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3955f7')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3955f9')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395600')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395606')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395608')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395609')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39560e')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395611')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395614')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39561b')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395620')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395621')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395628')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395631')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395634')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395635')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39563c')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395644')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395647')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395648')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39564a')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39564d')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395654')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395656')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395660')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395666')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39566a')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39566b')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39566e')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395674')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39567c')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39567d')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39567e')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395680')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39568a')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39568c')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39568d')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39568e')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39568f')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395690')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395693')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395694')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395696')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395697')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395698')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395699')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39569c')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39569f')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3956a4')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3956ab')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3956ad')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3956b1')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3956b2')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3956b8')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3956b9')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3956bf')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3956c0')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3956c1')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3956c2')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3956c3')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3956c8')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3956ca')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3956cf')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3956d6')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3956d8')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3956de')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3956df')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3956e0')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3956e7')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3956ed')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3956f0')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3956f2')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3956f6')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3956fc')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3956fd')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395704')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395705')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39570a')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39570c')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39570d')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395710')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395713')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395718')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395721')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39572c')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395741')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395744')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39575e')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39576a')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39576c')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395773')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395777')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39577c')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395794')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39579f')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3957a9')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3957b0')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3957bc')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3957c0')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3957c3')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3957c5')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3957cf')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3957db')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3957dc')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3957e4')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3957e8')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3957ea')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3957ed')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3957f1')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3957f4')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3957f9')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3957fe')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39580a')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39580d')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395812')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39581f')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395821')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395823')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395829')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39582a')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395831')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395834')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39583a')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39583d')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39583e')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39583f')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39584f')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395853')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395857')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39585d')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395862')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39586f')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395876')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39587a')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39587e')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395880')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395883')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395887')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395888')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395889')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39588e')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395890')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395892')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395893')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395894')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395899')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39589c')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39589e')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39589f')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958a8')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958aa')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958ab')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958ad')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958af')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958b0')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958b6')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958b7')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958b9')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958bf')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958c1')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958c2')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958c3')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958c7')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958c8')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958ca')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958cc')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958d2')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958d4')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958d8')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958da')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958db')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958df')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958e0')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958e2')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958e4')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958e8')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958ef')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958f5')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958f9')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958fb')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958fc')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3958fd')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395905')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395908')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39590b')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39590e')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39590f')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395910')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395913')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395914')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395916')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39591b')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39591d')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39591e')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39591f')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395923')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395925')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395929')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39592e')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39592f')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395932')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395933')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395937')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39593c')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39593d')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39593f')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395943')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395946')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395949')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39594b')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395952')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395953')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395957')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39595b')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395964')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395969')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39597b')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395980')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395981')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395989')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc39598a')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395990')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395993')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959a8')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959ad')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959b1')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959b7')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959be')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959c1')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959c3')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959c4')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959c6')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959c7')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959c8')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959c9')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959ca')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959cc')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959cd')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959ce')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959d0')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959d3')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959d5')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959dc')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959e1')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959e6')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959e7')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959e9')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959ea')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959eb')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959ec')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959ee')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959f1')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959f2')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959f5')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959f6')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959f8')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc3959fc')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a04')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a06')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a0a')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a0b')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a0c')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a0d')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a10')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a12')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a19')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a1b')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a1f')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a20')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a21')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a22')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a2d')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a2f')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a33')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a34')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a38')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a3a')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a3e')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a3f')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a43')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a45')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a55')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a59')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a5a')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a5f')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a64')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a65')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a68')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a6a')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a76')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a77')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a79')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a7b')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a7c')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a7e')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a81')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('640689993c7f636ebc395a84')},
# ...
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39eecc')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39eecd')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39eed0')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39eed2')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39eed7')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39eed8')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39eedf')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39eee2')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39eee3')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39eee4')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39eee5')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39eee6')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39eee7')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39eee9')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39eeee')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39eeef')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39eef5')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39eef8')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39eefb')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39eefe')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef04')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef10')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef11')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef13')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef14')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef21')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef3c')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef4a')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef4b')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef4c')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef50')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef52')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef53')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef54')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef56')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef57')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef5a')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef5b')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef5d')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef6b')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef72')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef7e')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef80')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef88')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef8d')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef93')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef94')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef95')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef98')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef9b')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39ef9d')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39efa4')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39efa7')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39efa8')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39efb6')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39efba')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39efc5')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39efca')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39efd0')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39efd5')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39efd8')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39efdb')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39efe5')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39efe8')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39efea')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39efec')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39eff3')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39eff8')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39eff9')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39effc')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39effd')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39effe')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f002')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f003')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f006')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f007')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f008')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f009')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f00b')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f010')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f011')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f012')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f014')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f015')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f017')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f019')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f01a')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f01b')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f01d')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f020')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f022')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f024')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f028')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f02e')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f032')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f033')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f035')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f03a')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f03b')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f041')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f047')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f04e')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f053')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f054')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f055')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f057')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f060')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f06e')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f06f')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f07a')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f07f')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f08e')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f08f')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f091')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f094')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f095')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f096')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': 1,
#         '_id': ObjectId('6406899b3c7f636ebc39f0aa')},
#     {   'BusinessType': 'Restaurant/Cafe/Canteen',
#         'BusinessTypeID': '',
#         '_id': ObjectId('640689a562e7a426474105bc')}]

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
coll.update_one(update_dict,{"$set":{"BusinessTypeID":1}})

# %%
# Confirm that the new restaurant was updated
coll.find_one({"BusinessName":"Penang Flavours"})
# Out:
# {'_id': ObjectId('640689a562e7a426474105bc'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
dover_count = coll.count_documents({"LocalAuthorityName":"Dover"})
dover_count
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
coll.delete_many({"LocalAuthorityName":"Dover"})

# %%
# Check if any remaining documents include Dover
dover_count = coll.count_documents({"LocalAuthorityName":"Dover"})
dover_count
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
pprint(coll.find_one(), indent=4)
# Out:
# {   'AddressLine1': 'East Cliff Pavilion',
#     'AddressLine2': 'Wear Bay Road',
#     'AddressLine3': 'Folkestone',
#     'AddressLine4': 'Kent',
#     'BusinessName': 'The Pavilion',
#     'BusinessType': 'Restaurant/Cafe/Canteen',
#     'BusinessTypeID': 1,
#     'ChangesByServerID': 0,
#     'Distance': 4591.765489457773,
#     'FHRSID': 1043695,
#     'LocalAuthorityBusinessID': 'PI/000073616',
#     'LocalAuthorityCode': '188',
#     'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#     'LocalAuthorityName': 'Folkestone and Hythe',
#     'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#     'NewRatingPending': False,
#     'Phone': '',
#     'PostCode': 'CT19 6BL',
#     'RatingDate': '2018-04-04T00:00:00',
#     'RatingKey': 'fhrs_5_en-gb',
#     'RatingValue': '5',
#     'RightToReply': '',
#     'SchemeType': 'FHRS',
#     '_id': ObjectId('640689993c7f636ebc39582a'),
#     'geocode': {'latitude': '51.083812', 'longitude': '1.195625'},
#     'links': [   {   'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#                      'rel': 'self'}],
#     'meta': {   'dataSource': None,
#                 'extractDate': '0001-01-01T00:00:00',
#                 'itemCount': 0,
#                 'pageNumber': 0,
#                 'pageSize': 0,
#                 'returncode': None,
#                 'totalCount': 0,
#                 'totalPages': 0},
#     'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers. Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude
update = [{"$set": {"geocode.longitude": {"$toDouble":"$geocode.longitude"}}}]
coll.update_many({}, update)

# %%
# Change the data type from String to Decimal for latitude
update = [{"$set": {"geocode.latitude": {"$toDouble":"$geocode.latitude"}}}]

coll.update_many({}, update)

# %%
# Check that the coordinates are now numbers
check = coll.find_one()
check
# Out:
# {'_id': ObjectId('640689993c7f636ebc39582a'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 1.195625, 'latitude': 51.083812},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}
